# %%
import yfinance as yf
import ta
import matplotlib.pyplot as plt

# %%
data = yf.download('FNGU',start = '2021-03-17')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4ef422fb2c01> in <module>
# ----> 1 data(index)
#
# NameError: name 'index' is not defined

# %%
rsi = ta.momentum.rsi(data['Close'])

# %%
mfi = ta.volume.money_flow_index(data['High'],data['Low'],data['Close'],data['Volume'])

# %%
macd = ta.trend.macd(data['Close'])

# %%
macd_sig = ta.trend.macd_signal(data['Close'])

# %%
plt.plot(rsi)

# %%
plt.plot(macd - macd_sig)

# %%
plt.plot(mfi)
